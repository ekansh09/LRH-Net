# %% [markdown]
# # Knowledge Distillation Techniques on LRH-Net

# %% [markdown]
# ## Vanilla KD

# %% [markdown]
# Final Challenge Metric Score 0.5948530450907572
#
# macro_f1 :  0.5746952979673264
#
# micro_f1 :  0.7304590115852764
#
# weighted_f1 :  0.7325198654585321

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.85      0.85      0.85        59
#                                prolonged qt interval       0.49      0.61      0.54       302
#                                  atrial fibrillation       0.74      0.92      0.82       695
#                                       atrial flutter       0.55      0.58      0.56        62
#                             left bundle branch block       0.71      0.91      0.80       209
#                                       qwave abnormal       0.33      0.24      0.28       202
#                                      t wave abnormal       0.45      0.75      0.56       934
#                                prolonged pr interval       0.53      0.53      0.53        68
#                                     low qrs voltages       0.43      0.41      0.42       112
#                                  1st degree av block       0.62      0.82      0.71       479
#                         premature atrial contraction       0.38      0.49      0.43       389
#                                  left axis deviation       0.63      0.92      0.75      1217
#                                    sinus bradycardia       0.61      0.90      0.73       471
#                                          bradycardia       0.43      0.57      0.49        58
#                                         sinus rhythm       0.87      0.98      0.92      4169
#                                    sinus tachycardia       0.76      0.90      0.82       482
#                   premature ventricular contractions       0.33      0.15      0.20       110
#                                     sinus arrhythmia       0.23      0.12      0.16       248
#                       left anterior fascicular block       0.68      0.82      0.74       361
#                                 right axis deviation       0.48      0.67      0.56        86
#                                     t wave inversion       0.18      0.35      0.24       221
#     nonspecific intraventricular conduction disorder       0.29      0.37      0.32       199
#                 incomplete right bundle branch block       0.46      0.70      0.55       322
#                   complete right bundle branch block       0.70      0.94      0.81       615
#
#                                            micro avg       0.66      0.83      0.73     12070
#                                            macro avg       0.53      0.65      0.57     12070
#                                         weighted avg       0.67      0.83      0.73     12070
#                                          samples avg       0.73      0.85      0.76     12070

# %% [markdown]
# ![__results___51_373 (1).png](attachment:5a8a30df-1be0-4076-9e56-16e6561a0b1a.png)

# %% [markdown]
# ## FitNets

# %% [markdown]
# Final Challenge Metric Score 0.5888125781901334
#
# macro_f1 :  0.5452016172193083
#
# micro_f1 :  0.7260671980928257
#
# weighted_f1 :  0.7162784005649554

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.90      0.80      0.85        59
#                                prolonged qt interval       0.39      0.65      0.49       302
#                                  atrial fibrillation       0.75      0.92      0.83       695
#                                       atrial flutter       0.31      0.76      0.44        62
#                             left bundle branch block       0.82      0.84      0.83       209
#                                       qwave abnormal       0.43      0.15      0.22       202
#                                      t wave abnormal       0.48      0.66      0.56       934
#                                prolonged pr interval       0.30      0.74      0.43        68
#                                     low qrs voltages       0.35      0.41      0.38       112
#                                  1st degree av block       0.57      0.85      0.68       479
#                         premature atrial contraction       0.33      0.44      0.37       389
#                                  left axis deviation       0.67      0.89      0.76      1217
#                                    sinus bradycardia       0.63      0.84      0.72       471
#                                          bradycardia       0.55      0.38      0.45        58
#                                         sinus rhythm       0.84      0.98      0.91      4169
#                                    sinus tachycardia       0.66      0.91      0.77       482
#                   premature ventricular contractions       0.38      0.15      0.21       110
#                                     sinus arrhythmia       0.30      0.06      0.10       248
#                       left anterior fascicular block       0.61      0.88      0.72       361
#                                 right axis deviation       0.65      0.53      0.59        86
#                                     t wave inversion       0.22      0.11      0.14       221
#     nonspecific intraventricular conduction disorder       0.35      0.29      0.31       199
#                 incomplete right bundle branch block       0.44      0.69      0.54       322
#                   complete right bundle branch block       0.70      0.95      0.80       615
#
#                                            micro avg       0.66      0.81      0.73     12070
#                                            macro avg       0.53      0.62      0.55     12070
#                                         weighted avg       0.66      0.81      0.72     12070
#                                          samples avg       0.73      0.84      0.75     12070

# %% [markdown]
# ![__results___55_373 (1).png](attachment:5ca0c9e1-888d-45c5-b74e-2a43af31b40b.png)

# %% [markdown]
# ## PS-KD

# %% [markdown]
# Final Challenge Metric Score 0.5580114265595846
#
#
# macro_f1 :  0.5109111297165462
#
# micro_f1 :  0.6805319980112223
#
# weighted_f1 :  0.6904307214044613

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.65      0.86      0.74        59
#                                prolonged qt interval       0.43      0.53      0.48       302
#                                  atrial fibrillation       0.67      0.93      0.78       695
#                                       atrial flutter       0.60      0.47      0.53        62
#                             left bundle branch block       0.78      0.89      0.83       209
#                                       qwave abnormal       0.25      0.18      0.21       202
#                                      t wave abnormal       0.42      0.67      0.52       934
#                                prolonged pr interval       0.37      0.37      0.37        68
#                                     low qrs voltages       0.34      0.31      0.32       112
#                                  1st degree av block       0.51      0.84      0.63       479
#                         premature atrial contraction       0.25      0.49      0.33       389
#                                  left axis deviation       0.56      0.93      0.70      1217
#                                    sinus bradycardia       0.59      0.81      0.69       471
#                                          bradycardia       0.31      0.57      0.40        58
#                                         sinus rhythm       0.83      0.98      0.90      4169
#                                    sinus tachycardia       0.64      0.90      0.75       482
#                   premature ventricular contractions       0.13      0.28      0.18       110
#                                     sinus arrhythmia       0.32      0.04      0.08       248
#                       left anterior fascicular block       0.58      0.86      0.69       361
#                                 right axis deviation       0.27      0.69      0.38        86
#                                     t wave inversion       0.18      0.16      0.15       221
#     nonspecific intraventricular conduction disorder       0.34      0.23      0.23       199
#                 incomplete right bundle branch block       0.39      0.70      0.50       322
#                   complete right bundle branch block       0.73      0.92      0.82       615
#
#                                            micro avg       0.60      0.81      0.68     12070
#                                            macro avg       0.46      0.61      0.51     12070
#                                         weighted avg       0.62      0.81      0.69     12070
#                                          samples avg       0.69      0.84      0.72     12070

# %% [markdown]
# ![__results___40_373 (1).png](attachment:91a9c123-139d-4720-b1b4-aa2f6c0dd872.png)

# %% [markdown]
# ## Cross-Layer

# %% [markdown]
# Final Challenge Metric Score 0.5903957195770426
#
#
# macro_f1 :  0.5504307913771559
#
# micro_f1 :  0.732845619958732
#
# weighted_f1 :  0.7236189875785305

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.88      0.83      0.85        59
#                                prolonged qt interval       0.44      0.64      0.52       302
#                                  atrial fibrillation       0.77      0.91      0.83       695
#                                       atrial flutter       0.55      0.52      0.53        62
#                             left bundle branch block       0.64      0.92      0.76       209
#                                       qwave abnormal       0.31      0.25      0.28       202
#                                      t wave abnormal       0.45      0.69      0.54       934
#                                prolonged pr interval       0.42      0.53      0.47        68
#                                     low qrs voltages       0.27      0.46      0.34       112
#                                  1st degree av block       0.57      0.84      0.68       479
#                         premature atrial contraction       0.38      0.49      0.42       389
#                                  left axis deviation       0.64      0.90      0.75      1217
#                                    sinus bradycardia       0.64      0.89      0.74       471
#                                          bradycardia       0.41      0.50      0.45        58
#                                         sinus rhythm       0.87      0.98      0.92      4169
#                                    sinus tachycardia       0.77      0.92      0.84       482
#                   premature ventricular contractions       0.25      0.12      0.16       110
#                                     sinus arrhythmia       0.26      0.06      0.10       248
#                       left anterior fascicular block       0.56      0.89      0.69       361
#                                 right axis deviation       0.51      0.62      0.56        86
#                                     t wave inversion       0.18      0.03      0.05       221
#     nonspecific intraventricular conduction disorder       0.32      0.39      0.35       199
#                 incomplete right bundle branch block       0.62      0.48      0.54       322
#                   complete right bundle branch block       0.75      0.93      0.83       615
#
#                                            micro avg       0.67      0.81      0.73     12070
#                                            macro avg       0.52      0.62      0.55     12070
#                                         weighted avg       0.67      0.81      0.72     12070
#                                          samples avg       0.74      0.84      0.76     12070

# %% [markdown]
# ![__results___53_613 (1).png](attachment:a0bbbe0e-7cd5-466d-bea5-605082a45356.png)
