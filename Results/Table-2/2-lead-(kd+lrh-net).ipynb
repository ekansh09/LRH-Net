# %% [markdown]
# # Knowledge Distillation Techniques on LRH-Net

# %% [markdown]
# ## Vanilla KD

# %% [markdown]
# Final Challenge Metric Score 0.5727122220419798
#
# macro_f1 :  0.5378747775171996
#
# micro_f1 :  0.7117993993559357
#
# weighted_f1 :  0.7127313895785137

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.92      0.83      0.88        59
#                                prolonged qt interval       0.36      0.70      0.48       302
#                                  atrial fibrillation       0.78      0.91      0.84       695
#                                       atrial flutter       0.50      0.60      0.54        62
#                             left bundle branch block       0.70      0.91      0.79       209
#                                       qwave abnormal       0.30      0.29      0.30       202
#                                      t wave abnormal       0.40      0.77      0.53       934
#                                prolonged pr interval       0.33      0.72      0.45        68
#                                     low qrs voltages       0.43      0.21      0.28       112
#                                  1st degree av block       0.51      0.87      0.64       479
#                         premature atrial contraction       0.42      0.48      0.45       389
#                                  left axis deviation       0.67      0.90      0.77      1217
#                                    sinus bradycardia       0.62      0.88      0.73       471
#                                          bradycardia       0.37      0.45      0.41        58
#                                         sinus rhythm       0.86      0.98      0.92      4169
#                                    sinus tachycardia       0.74      0.91      0.81       482
#                   premature ventricular contractions       0.24      0.25      0.25       110
#                                     sinus arrhythmia       0.07      0.00      0.01       248
#                       left anterior fascicular block       0.49      0.93      0.64       361
#                                 right axis deviation       0.50      0.76      0.60        86
#                                     t wave inversion       0.14      0.24      0.17       221
#     nonspecific intraventricular conduction disorder       0.28      0.31      0.29       199
#                 incomplete right bundle branch block       0.37      0.31      0.34       322
#                   complete right bundle branch block       0.72      0.90      0.80       615
#
#                                            micro avg       0.63      0.81      0.71     12070
#                                            macro avg       0.49      0.63      0.54     12070
#                                         weighted avg       0.64      0.81      0.71     12070
#                                          samples avg       0.72      0.85      0.75     12070

# %% [markdown]
# ![__results___51_373 (2).png](attachment:fbb4668d-9d07-4ff4-b417-cb0cd2264c76.png)

# %% [markdown]
# ## FitNets

# %% [markdown]
# Final Challenge Metric Score 0.5720347795815411
#
# macro_f1 :  0.5370039497104582
#
# micro_f1 :  0.7022398358161425
#
# weighted_f1 :  0.7105951255247324

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.88      0.85      0.86        59
#                                prolonged qt interval       0.39      0.62      0.47       302
#                                  atrial fibrillation       0.75      0.90      0.82       695
#                                       atrial flutter       0.46      0.45      0.46        62
#                             left bundle branch block       0.63      0.94      0.76       209
#                                       qwave abnormal       0.25      0.32      0.28       202
#                                      t wave abnormal       0.39      0.76      0.52       934
#                                prolonged pr interval       0.34      0.66      0.45        68
#                                     low qrs voltages       0.24      0.42      0.31       112
#                                  1st degree av block       0.51      0.83      0.63       479
#                         premature atrial contraction       0.32      0.60      0.42       389
#                                  left axis deviation       0.60      0.94      0.73      1217
#                                    sinus bradycardia       0.56      0.90      0.69       471
#                                          bradycardia       0.38      0.47      0.42        58
#                                         sinus rhythm       0.88      0.97      0.92      4169
#                                    sinus tachycardia       0.68      0.92      0.78       482
#                   premature ventricular contractions       0.33      0.17      0.23       110
#                                     sinus arrhythmia       0.32      0.09      0.14       248
#                       left anterior fascicular block       0.64      0.86      0.73       361
#                                 right axis deviation       0.48      0.74      0.58        86
#                                     t wave inversion       0.18      0.20      0.19       221
#     nonspecific intraventricular conduction disorder       0.25      0.42      0.31       199
#                 incomplete right bundle branch block       0.34      0.44      0.38       322
#                   complete right bundle branch block       0.71      0.92      0.80       615
#
#                                            micro avg       0.61      0.82      0.70     12070
#                                            macro avg       0.48      0.64      0.54     12070
#                                         weighted avg       0.64      0.82      0.71     12070
#                                          samples avg       0.70      0.85      0.73     12070

# %% [markdown]
# ![__results___55_373 (2).png](attachment:9facf6c4-a4fa-42f8-bb99-f768cf20379a.png)

# %% [markdown]
# ## PS-KD

# %% [markdown]
# Final Challenge Metric Score 0.5558149320391297
#
# macro_f1 :  0.4877816133259703
#
# micro_f1 :  0.6802525429673799
#
# weighted_f1 :  0.6815062427695137

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.75      0.85      0.79        59
#                                prolonged qt interval       0.27      0.74      0.40       302
#                                  atrial fibrillation       0.73      0.90      0.80       695
#                                       atrial flutter       0.23      0.74      0.35        62
#                             left bundle branch block       0.64      0.92      0.76       209
#                                       qwave abnormal       0.45      0.06      0.11       202
#                                      t wave abnormal       0.40      0.66      0.50       934
#                                prolonged pr interval       0.23      0.78      0.36        68
#                                     low qrs voltages       0.32      0.38      0.35       112
#                                  1st degree av block       0.48      0.84      0.61       479
#                         premature atrial contraction       0.31      0.40      0.35       389
#                                  left axis deviation       0.64      0.89      0.74      1217
#                                    sinus bradycardia       0.53      0.88      0.66       471
#                                          bradycardia       0.35      0.57      0.43        58
#                                         sinus rhythm       0.84      0.98      0.91      4169
#                                    sinus tachycardia       0.65      0.89      0.75       482
#                   premature ventricular contractions       0.33      0.19      0.24       110
#                                     sinus arrhythmia       0.27      0.03      0.05       248
#                       left anterior fascicular block       0.49      0.93      0.64       361
#                                 right axis deviation       0.38      0.73      0.50        86
#                                     t wave inversion       0.14      0.01      0.02       221
#     nonspecific intraventricular conduction disorder       0.15      0.53      0.24       199
#                 incomplete right bundle branch block       0.36      0.35      0.36       322
#                   complete right bundle branch block       0.67      0.92      0.77       615
#
#                                            micro avg       0.59      0.80      0.68     12070
#                                            macro avg       0.44      0.63      0.49     12070
#                                         weighted avg       0.61      0.80      0.68     12070
#                                          samples avg       0.68      0.84      0.71     12070

# %% [markdown]
# ![__results___40_373 (2).png](attachment:fc171ed2-be69-4cab-aaae-fde17da45e68.png)

# %% [markdown]
# ## Cross-Layer

# %% [markdown]
# Final Challenge Metric Score 0.5713221922422177
#
#
# macro_f1 :  0.5263662159012692
#
# micro_f1 :  0.7069693579239903
#
# weighted_f1 :  0.7041942047668236

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.93      0.86      0.89        59
#                                prolonged qt interval       0.32      0.80      0.46       302
#                                  atrial fibrillation       0.72      0.92      0.80       695
#                                       atrial flutter       0.57      0.52      0.54        62
#                             left bundle branch block       0.68      0.91      0.78       209
#                                       qwave abnormal       0.24      0.36      0.29       202
#                                      t wave abnormal       0.38      0.78      0.51       934
#                                prolonged pr interval       0.38      0.56      0.46        68
#                                     low qrs voltages       0.24      0.45      0.31       112
#                                  1st degree av block       0.56      0.82      0.67       479
#                         premature atrial contraction       0.38      0.48      0.42       389
#                                  left axis deviation       0.65      0.91      0.76      1217
#                                    sinus bradycardia       0.61      0.89      0.72       471
#                                          bradycardia       0.33      0.45      0.38        58
#                                         sinus rhythm       0.86      0.98      0.92      4169
#                                    sinus tachycardia       0.67      0.94      0.78       482
#                   premature ventricular contractions       0.19      0.18      0.18       110
#                                     sinus arrhythmia       0.37      0.05      0.09       248
#                       left anterior fascicular block       0.58      0.90      0.71       361
#                                 right axis deviation       0.41      0.76      0.53        86
#                                     t wave inversion       0.17      0.12      0.14       221
#     nonspecific intraventricular conduction disorder       0.40      0.23      0.29       199
#                 incomplete right bundle branch block       0.56      0.13      0.21       322
#                   complete right bundle branch block       0.72      0.89      0.80       615
#
#                                            micro avg       0.63      0.81      0.71     12070
#                                            macro avg       0.50      0.62      0.53     12070
#                                         weighted avg       0.65      0.81      0.70     12070
#                                          samples avg       0.71      0.84      0.74     12070

# %% [markdown]
# ![__results___53_613 (2).png](attachment:381faf89-2b3a-4495-b2f2-f327fbae06f9.png)
