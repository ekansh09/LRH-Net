# %% [markdown]
# # Knowledge Distillation Techniques on LRH-Net

# %% [markdown]
# ## Vanilla KD

# %% [markdown]
# Final Challenge Metric Score 0.6067303835800012
#
# macro_f1 :  0.5748949185766764
#
# micro_f1 :  0.7340886735400197
#
# weighted_f1 :  0.7379433950069587

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.82      0.83      0.82        59
#                                prolonged qt interval       0.37      0.72      0.49       302
#                                  atrial fibrillation       0.83      0.90      0.86       695
#                                       atrial flutter       0.53      0.63      0.57        62
#                             left bundle branch block       0.79      0.88      0.83       209
#                                       qwave abnormal       0.46      0.23      0.30       202
#                                      t wave abnormal       0.48      0.77      0.59       934
#                                prolonged pr interval       0.32      0.87      0.47        68
#                                     low qrs voltages       0.48      0.52      0.50       112
#                                  1st degree av block       0.60      0.84      0.70       479
#                         premature atrial contraction       0.40      0.53      0.45       389
#                                  left axis deviation       0.66      0.89      0.76      1217
#                                    sinus bradycardia       0.56      0.91      0.69       471
#                                          bradycardia       0.47      0.38      0.42        58
#                                         sinus rhythm       0.86      0.98      0.92      4169
#                                    sinus tachycardia       0.76      0.91      0.83       482
#                   premature ventricular contractions       0.26      0.17      0.21       110
#                                     sinus arrhythmia       0.24      0.12      0.16       248
#                       left anterior fascicular block       0.57      0.90      0.70       361
#                                 right axis deviation       0.48      0.65      0.55        86
#                                     t wave inversion       0.16      0.36      0.22       221
#     nonspecific intraventricular conduction disorder       0.40      0.24      0.30       199
#                 incomplete right bundle branch block       0.47      0.79      0.59       322
#                   complete right bundle branch block       0.79      0.95      0.86       615
#
#                                            micro avg       0.66      0.83      0.73     12070
#                                            macro avg       0.53      0.67      0.57     12070
#                                         weighted avg       0.67      0.83      0.74     12070
#                                          samples avg       0.73      0.86      0.76     12070

# %% [markdown]
# ![__results___51_373.png](attachment:6cb1b91a-dce2-45a9-b3c4-075670576916.png)

# %% [markdown]
# ## FitNets

# %% [markdown]
# Final Challenge Metric Score 0.6046378396616497
#
# macro_f1 :  0.5509219033845022
#
# micro_f1 :  0.7221620059252837
#
# weighted_f1 :  0.7227687517642193

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.94      0.78      0.85        59
#                                prolonged qt interval       0.37      0.69      0.48       302
#                                  atrial fibrillation       0.80      0.91      0.85       695
#                                       atrial flutter       0.49      0.58      0.53        62
#                             left bundle branch block       0.68      0.93      0.79       209
#                                       qwave abnormal       0.31      0.32      0.32       202
#                                      t wave abnormal       0.43      0.81      0.56       934
#                                prolonged pr interval       0.47      0.50      0.48        68
#                                     low qrs voltages       0.47      0.40      0.43       112
#                                  1st degree av block       0.56      0.85      0.67       479
#                         premature atrial contraction       0.31      0.51      0.39       389
#                                  left axis deviation       0.68      0.89      0.77      1217
#                                    sinus bradycardia       0.63      0.88      0.74       471
#                                          bradycardia       0.52      0.41      0.46        58
#                                         sinus rhythm       0.85      0.98      0.91      4169
#                                    sinus tachycardia       0.80      0.84      0.82       482
#                   premature ventricular contractions       0.25      0.01      0.02       110
#                                     sinus arrhythmia       0.27      0.02      0.03       248
#                       left anterior fascicular block       0.42      0.96      0.58       361
#                                 right axis deviation       0.72      0.49      0.58        86
#                                     t wave inversion       0.16      0.24      0.19       221
#     nonspecific intraventricular conduction disorder       0.32      0.33      0.33       199
#                 incomplete right bundle branch block       0.49      0.75      0.59       322
#                   complete right bundle branch block       0.73      0.97      0.84       615
#
#                                            micro avg       0.64      0.83      0.72     12070
#                                            macro avg       0.53      0.63      0.55     12070
#                                         weighted avg       0.66      0.83      0.72     12070
#                                          samples avg       0.72      0.86      0.75     12070

# %% [markdown]
# ![__results___55_373.png](attachment:2539508b-11c2-4765-8882-168a0047bcc5.png)

# %% [markdown]
# ## PS-KD

# %% [markdown]
# Final Challenge Metric Score 0.5780631793361969
#
#
# macro_f1 :  0.5272921128455056
#
# micro_f1 :  0.6862400496226609
#
# weighted_f1 :  0.6990594609616528

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.98      0.76      0.86        59
#                                prolonged qt interval       0.39      0.57      0.46       302
#                                  atrial fibrillation       0.79      0.89      0.84       695
#                                       atrial flutter       0.56      0.50      0.53        62
#                             left bundle branch block       0.73      0.92      0.82       209
#                                       qwave abnormal       0.20      0.35      0.26       202
#                                      t wave abnormal       0.41      0.78      0.54       934
#                                prolonged pr interval       0.37      0.41      0.39        68
#                                     low qrs voltages       0.37      0.43      0.40       112
#                                  1st degree av block       0.52      0.83      0.64       479
#                         premature atrial contraction       0.24      0.50      0.32       389
#                                  left axis deviation       0.60      0.90      0.72      1217
#                                    sinus bradycardia       0.50      0.90      0.64       471
#                                          bradycardia       0.35      0.52      0.42        58
#                                         sinus rhythm       0.83      0.98      0.90      4169
#                                    sinus tachycardia       0.58      0.93      0.71       482
#                   premature ventricular contractions       0.19      0.06      0.10       110
#                                     sinus arrhythmia       0.00      0.00      0.00       248
#                       left anterior fascicular block       0.62      0.83      0.71       361
#                                 right axis deviation       0.45      0.62      0.52        86
#                                     t wave inversion       0.14      0.52      0.22       221
#     nonspecific intraventricular conduction disorder       0.27      0.29      0.28       199
#                 incomplete right bundle branch block       0.40      0.78      0.53       322
#                   complete right bundle branch block       0.80      0.92      0.85       615
#
#                                            micro avg       0.59      0.82      0.69     12070
#                                            macro avg       0.47      0.63      0.53     12070
#                                         weighted avg       0.62      0.82      0.70     12070
#                                          samples avg       0.68      0.85      0.73     12070

# %% [markdown]
# ![__results___40_373.png](attachment:b36379e4-3af0-4d7e-b2f5-929553778e3b.png)

# %% [markdown]
# ## Cross-Layer

# %% [markdown]
# Final Challenge Metric Score 0.6017222458482415
#
#
# macro_f1 :  0.5566329601333136
#
# micro_f1 :  0.7333868847670513
#
# weighted_f1 :  0.7279824891785072

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.89      0.83      0.86        59
#                                prolonged qt interval       0.49      0.60      0.54       302
#                                  atrial fibrillation       0.72      0.93      0.81       695
#                                       atrial flutter       0.38      0.71      0.49        62
#                             left bundle branch block       0.85      0.86      0.85       209
#                                       qwave abnormal       0.33      0.32      0.32       202
#                                      t wave abnormal       0.43      0.81      0.56       934
#                                prolonged pr interval       0.37      0.69      0.48        68
#                                     low qrs voltages       0.33      0.62      0.43       112
#                                  1st degree av block       0.59      0.83      0.69       479
#                         premature atrial contraction       0.41      0.52      0.46       389
#                                  left axis deviation       0.64      0.91      0.75      1217
#                                    sinus bradycardia       0.62      0.88      0.73       471
#                                          bradycardia       0.41      0.41      0.41        58
#                                         sinus rhythm       0.87      0.98      0.92      4169
#                                    sinus tachycardia       0.72      0.91      0.80       482
#                   premature ventricular contractions       0.19      0.04      0.06       110
#                                     sinus arrhythmia       0.23      0.02      0.04       248
#                       left anterior fascicular block       0.51      0.92      0.66       361
#                                 right axis deviation       0.54      0.59      0.57        86
#                                     t wave inversion       0.21      0.11      0.14       221
#     nonspecific intraventricular conduction disorder       0.29      0.37      0.33       199
#                 incomplete right bundle branch block       0.50      0.75      0.60       322
#                   complete right bundle branch block       0.74      0.96      0.84       615
#
#                                            micro avg       0.66      0.83      0.73     12070
#                                            macro avg       0.51      0.65      0.56     12070
#                                         weighted avg       0.66      0.83      0.73     12070
#                                          samples avg       0.73      0.86      0.76     12070

# %% [markdown]
# ![__results___53_613.png](attachment:ee86019e-b758-424f-ba3d-ba3f143faa81.png)
