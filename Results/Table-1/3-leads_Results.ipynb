# %% [markdown]
# # SE-Resnet

# %% [markdown]
# Final Challenge Metric Score 0.6537372899928628
#
# macro_f1 :  0.6114433132226541
#
# micro_f1 :  0.7542544749953866
#
# weighted_f1 :  0.7623492749215373

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.96      0.80      0.87        59
#                                prolonged qt interval       0.50      0.70      0.58       302
#                                  atrial fibrillation       0.81      0.93      0.86       695
#                                       atrial flutter       0.63      0.58      0.61        62
#                             left bundle branch block       0.74      0.89      0.81       209
#                                       qwave abnormal       0.27      0.30      0.28       202
#                                      t wave abnormal       0.43      0.79      0.56       934
#                                prolonged pr interval       0.50      0.54      0.52        68
#                                     low qrs voltages       0.34      0.44      0.38       112
#                                  1st degree av block       0.60      0.85      0.71       479
#                         premature atrial contraction       0.49      0.82      0.61       389
#                                  left axis deviation       0.67      0.90      0.76      1217
#                                    sinus bradycardia       0.74      0.91      0.82       471
#                                          bradycardia       0.54      0.64      0.58        58
#                                         sinus rhythm       0.91      0.98      0.94      4169
#                                    sinus tachycardia       0.77      0.95      0.85       482
#                   premature ventricular contractions       0.29      0.45      0.35       110
#                                     sinus arrhythmia       0.48      0.67      0.56       248
#                       left anterior fascicular block       0.54      0.93      0.68       361
#                                 right axis deviation       0.57      0.58      0.57        86
#                                     t wave inversion       0.33      0.01      0.03       221
#     nonspecific intraventricular conduction disorder       0.35      0.31      0.33       199
#                 incomplete right bundle branch block       0.48      0.67      0.56       322
#                   complete right bundle branch block       0.79      0.92      0.85       615
#
#                                            micro avg       0.68      0.85      0.75     12070
#                                            macro avg       0.57      0.69      0.61     12070
#                                         weighted avg       0.70      0.85      0.75     12070
#                                          samples avg       0.76      0.88      0.79     12070

# %% [markdown]
# ![__results___40_373.png](attachment:dcf293b6-7c20-4323-8c32-650a06240f9e.png)

# %% [markdown]
# # LRH-Net

# %% [markdown]
# Final Challenge Metric Score 0.5849210038436169
#
# macro_f1 :  0.548691311130185
#
# micro_f1 :  0.7133534136546185
#
# weighted_f1 :  0.7166969585183525

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.89      0.83      0.86        59
#                                prolonged qt interval       0.40      0.65      0.49       302
#                                  atrial fibrillation       0.76      0.91      0.83       695
#                                       atrial flutter       0.44      0.55      0.49        62
#                             left bundle branch block       0.65      0.93      0.76       209
#                                       qwave abnormal       0.32      0.26      0.28       202
#                                      t wave abnormal       0.43      0.72      0.54       934
#                                prolonged pr interval       0.34      0.68      0.45        68
#                                     low qrs voltages       0.35      0.32      0.34       112
#                                  1st degree av block       0.51      0.88      0.65       479
#                         premature atrial contraction       0.41      0.44      0.43       389
#                                  left axis deviation       0.62      0.92      0.74      1217
#                                    sinus bradycardia       0.58      0.88      0.70       471
#                                          bradycardia       0.39      0.55      0.45        58
#                                         sinus rhythm       0.85      0.98      0.91      4169
#                                    sinus tachycardia       0.69      0.93      0.79       482
#                   premature ventricular contractions       0.23      0.26      0.25       110
#                                     sinus arrhythmia       0.18      0.07      0.10       248
#                       left anterior fascicular block       0.57      0.92      0.70       361
#                                 right axis deviation       0.49      0.52      0.51        86
#                                     t wave inversion       0.16      0.33      0.22       221
#     nonspecific intraventricular conduction disorder       0.26      0.34      0.29       199
#                 incomplete right bundle branch block       0.48      0.65      0.55       322
#                   complete right bundle branch block       0.79      0.92      0.85       615
#
#                                            micro avg       0.63      0.82      0.71     12070
#                                            macro avg       0.49      0.64      0.55     12070
#                                         weighted avg       0.64      0.82      0.72     12070
#                                          samples avg       0.71      0.85      0.75     12070

# %% [markdown]
# ![__results___40_373.png](attachment:910bdcad-8de5-4ec8-81d7-ad9934c1daca.png)

# %% [markdown]
# # 1D-CNN

# %% [markdown]
# Final Challenge Metric Score 0.569226775774082
#
# macro_f1 :  0.5334608264855093
#
# micro_f1 :  0.6764897260273972
#
# weighted_f1 :  0.7012947181321386

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.93      0.63      0.75        59
#                                prolonged qt interval       0.41      0.61      0.49       302
#                                  atrial fibrillation       0.82      0.89      0.85       695
#                                       atrial flutter       0.55      0.44      0.49        62
#                             left bundle branch block       0.72      0.90      0.80       209
#                                       qwave abnormal       0.14      0.01      0.02       202
#                                      t wave abnormal       0.38      0.68      0.49       934
#                                prolonged pr interval       0.36      0.62      0.45        68
#                                     low qrs voltages       0.24      0.40      0.30       112
#                                  1st degree av block       0.54      0.76      0.63       479
#                         premature atrial contraction       0.43      0.63      0.41       389
#                                  left axis deviation       0.60      0.87      0.71      1217
#                                    sinus bradycardia       0.55      0.94      0.70       471
#                                          bradycardia       0.44      0.64      0.52        58
#                                         sinus rhythm       0.83      0.97      0.89      4169
#                                    sinus tachycardia       0.72      0.92      0.81       482
#                   premature ventricular contractions       0.44      0.18      0.26       110
#                                     sinus arrhythmia       0.31      0.50      0.38       248
#                       left anterior fascicular block       0.50      0.91      0.55       361
#                                 right axis deviation       0.38      0.50      0.43        86
#                                     t wave inversion       0.20      0.14      0.17       221
#     nonspecific intraventricular conduction disorder       0.17      0.38      0.24       199
#                 incomplete right bundle branch block       0.38      0.59      0.46       322
#                   complete right bundle branch block       0.73      0.89      0.81       615
#
#                                            micro avg       0.61      0.81      0.68     12070
#                                            macro avg       0.49      0.62      0.53     12070
#                                         weighted avg       0.63      0.81      0.70     12070
#                                          samples avg       0.69      0.84      0.73     12070

# %% [markdown]
# ![__results___40_373.png](attachment:12480666-2059-4b04-b7c8-515d36bebeb3.png)
