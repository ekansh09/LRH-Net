# %% [markdown]
# # SE-Resnet

# %% [markdown]
# Final Challenge Metric Score 0.6334262147361708
#
# macro_f1 :  0.6114280426833602
#
# micro_f1 :  0.7486143523920654
#
# weighted_f1 :  0.7604924228860679

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.91      0.86      0.89        59
#                                prolonged qt interval       0.46      0.71      0.56       302
#                                  atrial fibrillation       0.88      0.90      0.89       695
#                                       atrial flutter       0.52      0.69      0.60        62
#                             left bundle branch block       0.77      0.90      0.83       209
#                                       qwave abnormal       0.25      0.33      0.29       202
#                                      t wave abnormal       0.43      0.75      0.54       934
#                                prolonged pr interval       0.34      0.62      0.44        68
#                                     low qrs voltages       0.29      0.47      0.36       112
#                                  1st degree av block       0.61      0.82      0.70       479
#                         premature atrial contraction       0.52      0.78      0.63       389
#                                  left axis deviation       0.66      0.93      0.77      1217
#                                    sinus bradycardia       0.75      0.90      0.82       471
#                                          bradycardia       0.44      0.64      0.52        58
#                                         sinus rhythm       0.89      0.99      0.94      4169
#                                    sinus tachycardia       0.82      0.93      0.87       482
#                   premature ventricular contractions       0.37      0.45      0.40       110
#                                     sinus arrhythmia       0.50      0.71      0.58       248
#                       left anterior fascicular block       0.63      0.88      0.74       361
#                                 right axis deviation       0.55      0.74      0.63        86
#                                     t wave inversion       0.16      0.19      0.18       221
#     nonspecific intraventricular conduction disorder       0.29      0.33      0.31       199
#                 incomplete right bundle branch block       0.32      0.46      0.38       322
#                   complete right bundle branch block       0.73      0.91      0.81       615
#
#                                            micro avg       0.67      0.85      0.75     12070
#                                            macro avg       0.55      0.70      0.61     12070
#                                         weighted avg       0.69      0.85      0.76     12070
#                                          samples avg       0.75      0.88      0.78     12070

# %% [markdown]
# ![__results___40_373.png](attachment:f5cc327e-d15a-4038-b52a-f176096b64f5.png)

# %% [markdown]
# # LRH-Net

# %% [markdown]
# Final Challenge Metric Score 0.5665938157231809
#
# macro_f1 :  0.536122442769127
#
# micro_f1 :  0.7021125257841951
#
# weighted_f1 :  0.7052928142601415

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.85      0.86      0.86        59
#                                prolonged qt interval       0.42      0.58      0.48       302
#                                  atrial fibrillation       0.76      0.91      0.83       695
#                                       atrial flutter       0.41      0.61      0.49        62
#                             left bundle branch block       0.71      0.92      0.80       209
#                                       qwave abnormal       0.26      0.31      0.28       202
#                                      t wave abnormal       0.39      0.72      0.51       934
#                                prolonged pr interval       0.33      0.72      0.45        68
#                                     low qrs voltages       0.30      0.47      0.36       112
#                                  1st degree av block       0.51      0.85      0.64       479
#                         premature atrial contraction       0.31      0.53      0.39       389
#                                  left axis deviation       0.64      0.92      0.75      1217
#                                    sinus bradycardia       0.60      0.89      0.72       471
#                                          bradycardia       0.29      0.59      0.39        58
#                                         sinus rhythm       0.85      0.98      0.91      4169
#                                    sinus tachycardia       0.69      0.93      0.79       482
#                   premature ventricular contractions       0.21      0.32      0.26       110
#                                     sinus arrhythmia       0.12      0.02      0.03       248
#                       left anterior fascicular block       0.60      0.89      0.71       361
#                                 right axis deviation       0.49      0.73      0.59        86
#                                     t wave inversion       0.17      0.16      0.17       221
#     nonspecific intraventricular conduction disorder       0.28      0.36      0.32       199
#                 incomplete right bundle branch block       0.32      0.40      0.36       322
#                   complete right bundle branch block       0.68      0.91      0.78       615
#
#                                            micro avg       0.62      0.82      0.70     12070
#                                            macro avg       0.47      0.65      0.54     12070
#                                         weighted avg       0.63      0.82      0.71     12070
#                                          samples avg       0.70      0.85      0.74     12070

# %% [markdown]
# ![__results___40_373.png](attachment:43015e23-ae58-4ec5-9dd5-8ff634358d38.png)

# %% [markdown]
# # 1D-CNN

# %% [markdown]
# Final Challenge Metric Score 0.5586823561789802
#
#
# macro_f1 :  0.5210752268921649
#
# micro_f1 :  0.6716109553590684
#
# weighted_f1 :  0.700463698044765

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.93      0.69      0.80        59
#                                prolonged qt interval       0.35      0.69      0.46       302
#                                  atrial fibrillation       0.79      0.88      0.81       695
#                                       atrial flutter       0.15      0.76      0.26        62
#                             left bundle branch block       0.56      0.91      0.70       209
#                                       qwave abnormal       0.28      0.15      0.20       202
#                                      t wave abnormal       0.41      0.60      0.49       934
#                                prolonged pr interval       0.37      0.66      0.47        68
#                                     low qrs voltages       0.31      0.28      0.29       112
#                                  1st degree av block       0.63      0.71      0.66       479
#                         premature atrial contraction       0.50      0.62      0.55       389
#                                  left axis deviation       0.61      0.88      0.60      1217
#                                    sinus bradycardia       0.68      0.87      0.76       471
#                                          bradycardia       0.51      0.52      0.51        58
#                                         sinus rhythm       0.84      0.97      0.90      4169
#                                    sinus tachycardia       0.67      0.95      0.79       482
#                   premature ventricular contractions       0.20      0.33      0.25       110
#                                     sinus arrhythmia       0.32      0.48      0.38       248
#                       left anterior fascicular block       0.44      0.95      0.60       361
#                                 right axis deviation       0.26      0.71      0.38        86
#                                     t wave inversion       0.16      0.27      0.20       221
#     nonspecific intraventricular conduction disorder       0.28      0.19      0.22       199
#                 incomplete right bundle branch block       0.33      0.26      0.29       322
#                   complete right bundle branch block       0.72      0.85      0.72       615
#
#                                            micro avg       0.61      0.80      0.67     12070
#                                            macro avg       0.47      0.63      0.52     12070
#                                         weighted avg       0.64      0.80      0.70     12070
#                                          samples avg       0.71      0.84      0.73     12070

# %% [markdown]
# ![__results___40_373.png](attachment:8520c81b-4f50-4395-951b-67c28e294922.png)
