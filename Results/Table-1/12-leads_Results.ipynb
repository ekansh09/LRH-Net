# %% [markdown]
# # SE-Resnet

# %% [markdown]
# Final Challenge Metric Score 0.6743379910933821
#
# macro_f1 :  0.6362934219756738
#
# micro_f1 :  0.7664709673940397
#
# weighted_f1 :  0.7738045848949232

# %% [markdown]
#                                                          precision    recall  f1-score   support
#
#                                        pacing rhythm       0.97      0.97      0.97        60
#                                prolonged qt interval       0.50      0.74      0.59       304
#                                  atrial fibrillation       0.85      0.92      0.88       695
#                                       atrial flutter       0.41      0.72      0.53        64
#                             left bundle branch block       0.73      0.90      0.81       208
#                                       qwave abnormal       0.66      0.13      0.29       203
#                                      t wave abnormal       0.53      0.76      0.62       935
#                                prolonged pr interval       0.44      0.82      0.57        68
#                                     low qrs voltages       0.33      0.66      0.44       112
#                                  1st degree av block       0.66      0.86      0.74       478
#                         premature atrial contraction       0.51      0.83      0.63       389
#                                  left axis deviation       0.64      0.93      0.76      1217
#                                    sinus bradycardia       0.83      0.87      0.85       472
#                                          bradycardia       0.38      0.82      0.55        57
#                                         sinus rhythm       0.88      0.99      0.93      4169
#                                    sinus tachycardia       0.75      0.94      0.84       481
#                   premature ventricular contractions       0.31      0.49      0.38       109
#                                     sinus arrhythmia       0.47      0.75      0.58       247
#                       left anterior fascicular block       0.58      0.92      0.72       361
#                                 right axis deviation       0.60      0.67      0.64        86
#                                     t wave inversion       0.20      0.45      0.28       223
#     nonspecific intraventricular conduction disorder       0.25      0.42      0.32       200
#                 incomplete right bundle branch block       0.48      0.80      0.66       321
#                   complete right bundle branch block       0.72      0.98      0.83       608
#
#                                            micro avg       0.67      0.88      0.77     12067
#                                            macro avg       0.57      0.77      0.64     12067
#                                         weighted avg       0.70      0.88      0.77     12067
#                                          samples avg       0.76      0.91      0.80     12067

# %% [markdown]
# ![download.png](attachment:84985f5a-0026-419b-9e7c-a302debec502.png)

# %% [markdown]
# # LRH-Net

# %% [markdown]
# Final Challenge Metric Score 0.6046330295580222
#
# macro_f1 :  0.5642422988098243
#
# micro_f1 :  0.727647905043212
#
# weighted_f1 :  0.7232271988857365

# %% [markdown]
#                                                      precision    recall  f1-score   support
#
#                                        pacing rhythm       0.92      0.95      0.93        60
#                                prolonged qt interval       0.42      0.64      0.51       304
#                                  atrial fibrillation       0.78      0.91      0.84       695
#                                       atrial flutter       0.54      0.64      0.59        64
#                             left bundle branch block       0.80      0.87      0.83       208
#                                       qwave abnormal       0.27      0.28      0.27       203
#                                      t wave abnormal       0.43      0.79      0.55       935
#                                prolonged pr interval       0.39      0.72      0.51        68
#                                     low qrs voltages       0.41      0.46      0.43       112
#                                  1st degree av block       0.59      0.89      0.71       478
#                         premature atrial contraction       0.35      0.44      0.39       389
#                                  left axis deviation       0.63      0.92      0.75      1217
#                                    sinus bradycardia       0.53      0.91      0.67       472
#                                          bradycardia       0.34      0.70      0.45        57
#                                         sinus rhythm       0.85      0.98      0.91      4169
#                                    sinus tachycardia       0.71      0.87      0.78       481
#                   premature ventricular contractions       0.23      0.17      0.19       109
#                                     sinus arrhythmia       0.11      0.00      0.01       247
#                       left anterior fascicular block       0.61      0.88      0.72       361
#                                 right axis deviation       0.47      0.72      0.57        86
#                                     t wave inversion       0.19      0.12      0.15       223
#     nonspecific intraventricular conduction disorder       0.31      0.30      0.31       200
#                 incomplete right bundle branch block       0.58      0.69      0.63       321
#                   complete right bundle branch block       0.76      0.94      0.84       608
#
#                                            micro avg       0.65      0.83      0.73     12067
#                                            macro avg       0.51      0.66      0.56     12067
#                                         weighted avg       0.65      0.83      0.72     12067
#                                          samples avg       0.73      0.86      0.76     12067

# %% [markdown]
# ![download.png](attachment:a056c89e-4471-45db-a1af-ba0faea832d0.png)

# %% [markdown]
# # 1D-CNN

# %% [markdown]
# Final Challenge Metric Score 0.5865801635466527
#
#
# macro_f1 :  0.5465467486645703
#
# micro_f1 :  0.6950211188143328
#
# weighted_f1 :  0.71612982301208

# %% [markdown]
#                                                      precision    recall  f1-score   support
#
#                                        pacing rhythm       0.70      0.93      0.80        60
#                                prolonged qt interval       0.43      0.60      0.50       304
#                                  atrial fibrillation       0.81      0.88      0.84       695
#                                       atrial flutter       0.40      0.52      0.45        64
#                             left bundle branch block       0.60      0.89      0.72       208
#                                       qwave abnormal       0.32      0.21      0.25       203
#                                      t wave abnormal       0.44      0.74      0.55       935
#                                prolonged pr interval       0.45      0.40      0.42        68
#                                     low qrs voltages       0.26      0.49      0.31       112
#                                  1st degree av block       0.51      0.86      0.64       478
#                         premature atrial contraction       0.39      0.67      0.49       389
#                                  left axis deviation       0.57      0.94      0.71      1217
#                                    sinus bradycardia       0.66      0.87      0.75       472
#                                          bradycardia       0.53      0.63      0.58        57
#                                         sinus rhythm       0.82      0.98      0.89      4169
#                                    sinus tachycardia       0.67      0.94      0.78       481
#                   premature ventricular contractions       0.45      0.17      0.24       109
#                                     sinus arrhythmia       0.43      0.46      0.44       247
#                       left anterior fascicular block       0.59      0.88      0.70       361
#                                 right axis deviation       0.50      0.62      0.50        86
#                                     t wave inversion       0.24      0.24      0.24       223
#     nonspecific intraventricular conduction disorder       0.22      0.38      0.28       200
#                 incomplete right bundle branch block       0.39      0.62      0.47       321
#                   complete right bundle branch block       0.74      0.94      0.83       608
#
#                                            micro avg       0.62      0.83      0.70     12067
#                                            macro avg       0.50      0.66      0.55     12067
#                                         weighted avg       0.64      0.83      0.72     12067
#                                          samples avg       0.70      0.87      0.75     12067

# %% [markdown]
# ![download.png](attachment:44757ffe-4454-4e2f-bdb7-eb4791148202.png)
