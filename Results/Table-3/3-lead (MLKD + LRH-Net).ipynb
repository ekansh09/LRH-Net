# %% [markdown]
# # Multi-Level Knowledge Distillation Methods (using Vanilla KD) on LRH-Net

# %% [markdown]
# ## Sequential MLKD

# %% [markdown]
# Final Challenge Metric Score 0.6038530450907572
#
# macro_f1 :  0.5637952979673264
#
# micro_f1 :  0.7344290115852764
#
# weighted_f1 :  0.7325198654585321

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.85      0.85      0.85        59
#                                prolonged qt interval       0.49      0.61      0.54       302
#                                  atrial fibrillation       0.74      0.92      0.82       695
#                                       atrial flutter       0.55      0.58      0.56        62
#                             left bundle branch block       0.71      0.91      0.80       209
#                                       qwave abnormal       0.33      0.24      0.28       202
#                                      t wave abnormal       0.45      0.75      0.56       934
#                                prolonged pr interval       0.53      0.53      0.53        68
#                                     low qrs voltages       0.43      0.41      0.42       112
#                                  1st degree av block       0.62      0.82      0.71       479
#                         premature atrial contraction       0.38      0.49      0.43       389
#                                  left axis deviation       0.63      0.92      0.75      1217
#                                    sinus bradycardia       0.61      0.90      0.73       471
#                                          bradycardia       0.43      0.57      0.49        58
#                                         sinus rhythm       0.87      0.98      0.92      4169
#                                    sinus tachycardia       0.76      0.90      0.82       482
#                   premature ventricular contractions       0.33      0.15      0.20       110
#                                     sinus arrhythmia       0.23      0.12      0.16       248
#                       left anterior fascicular block       0.68      0.82      0.74       361
#                                 right axis deviation       0.48      0.67      0.56        86
#                                     t wave inversion       0.18      0.35      0.24       221
#     nonspecific intraventricular conduction disorder       0.29      0.37      0.32       199
#                 incomplete right bundle branch block       0.46      0.70      0.55       322
#                   complete right bundle branch block       0.70      0.94      0.81       615
#
#                                            micro avg       0.66      0.83      0.73     12070
#                                            macro avg       0.53      0.65      0.56     12070
#                                         weighted avg       0.67      0.83      0.73     12070
#                                          samples avg       0.73      0.85      0.76     12070

# %% [markdown]
# ![__results___51_373 (1).png](attachment:5a8a30df-1be0-4076-9e56-16e6561a0b1a.png)

# %% [markdown]
# ## Parallel MLKD

# %% [markdown]
# Final Challenge Metric Score 0.6035683187276053
#
# macro_f1 :  0.5631237698572328
#
# micro_f1 :  0.7251167503406727
#
# weighted_f1 :  0.7314979603139353

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.89      0.86      0.88        59
#                                prolonged qt interval       0.49      0.59      0.54       302
#                                  atrial fibrillation       0.79      0.92      0.85       695
#                                       atrial flutter       0.45      0.56      0.50        62
#                             left bundle branch block       0.69      0.91      0.79       209
#                                       qwave abnormal       0.28      0.42      0.34       202
#                                      t wave abnormal       0.42      0.80      0.55       934
#                                prolonged pr interval       0.35      0.68      0.46        68
#                                     low qrs voltages       0.30      0.47      0.37       112
#                                  1st degree av block       0.56      0.87      0.68       479
#                         premature atrial contraction       0.42      0.53      0.47       389
#                                  left axis deviation       0.64      0.92      0.75      1217
#                                    sinus bradycardia       0.60      0.90      0.72       471
#                                          bradycardia       0.32      0.55      0.41        58
#                                         sinus rhythm       0.87      0.98      0.92      4169
#                                    sinus tachycardia       0.70      0.93      0.80       482
#                   premature ventricular contractions       0.21      0.25      0.23       110
#                                     sinus arrhythmia       0.19      0.06      0.09       248
#                       left anterior fascicular block       0.62      0.86      0.72       361
#                                 right axis deviation       0.48      0.71      0.57        86
#                                     t wave inversion       0.18      0.29      0.22       221
#     nonspecific intraventricular conduction disorder       0.28      0.36      0.32       199
#                 incomplete right bundle branch block       0.45      0.71      0.55       322
#                   complete right bundle branch block       0.73      0.94      0.82       615
#
#                                            micro avg       0.64      0.84      0.73     12070
#                                            macro avg       0.50      0.67      0.56     12070
#                                         weighted avg       0.66      0.84      0.73     12070
#                                          samples avg       0.72      0.87      0.76     12070

# %% [markdown]
# ![__results___51_373 (5).png](attachment:a96482d0-87e0-4ae0-b4cc-777157af9c90.png)
