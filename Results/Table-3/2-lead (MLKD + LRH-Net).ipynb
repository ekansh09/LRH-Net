# %% [markdown]
# # Multi-Level Knowledge Distillation Methods (using Vanilla KD) on LRH-Net

# %% [markdown]
# ## Sequential MLKD

# %% [markdown]
# Final Challenge Metric Score 0.5836362565652722
#
# macro_f1 :  0.5267461901143573
#
# micro_f1 :  0.7142570855567094
#
# weighted_f1 :  0.7281050023992224

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.91      0.81      0.86        59
#                                prolonged qt interval       0.47      0.63      0.53       302
#                                  atrial fibrillation       0.76      0.91      0.83       695
#                                       atrial flutter       0.51      0.61      0.55        62
#                             left bundle branch block       0.71      0.90      0.79       209
#                                       qwave abnormal       0.28      0.39      0.32       202
#                                      t wave abnormal       0.41      0.82      0.54       934
#                                prolonged pr interval       0.39      0.60      0.42        68
#                                     low qrs voltages       0.31      0.46      0.37       112
#                                  1st degree av block       0.56      0.87      0.68       479
#                         premature atrial contraction       0.42      0.50      0.46       389
#                                  left axis deviation       0.65      0.90      0.76      1217
#                                    sinus bradycardia       0.51      0.93      0.62       471
#                                          bradycardia       0.31      0.59      0.41        58
#                                         sinus rhythm       0.88      0.98      0.92      4169
#                                    sinus tachycardia       0.68      0.94      0.79       482
#                   premature ventricular contractions       0.25      0.27      0.26       110
#                                     sinus arrhythmia       0.24      0.09      0.13       248
#                       left anterior fascicular block       0.61      0.85      0.71       361
#                                 right axis deviation       0.51      0.60      0.56        86
#                                     t wave inversion       0.18      0.23      0.20       221
#     nonspecific intraventricular conduction disorder       0.31      0.35      0.33       199
#                 incomplete right bundle branch block       0.46      0.68      0.51       322
#                   complete right bundle branch block       0.73      0.94      0.82       615
#
#                                            micro avg       0.64      0.84      0.71     12070
#                                            macro avg       0.50      0.66      0.53     12070
#                                         weighted avg       0.66      0.84      0.73     12070
#                                          samples avg       0.72      0.86      0.75     12070

# %% [markdown]
# ![__results___51_373 (6).png](attachment:40520944-8bea-4b2f-8e1f-46b1f39c280a.png)

# %% [markdown]
# ## Parallel MLKD

# %% [markdown]
# Final Challenge Metric Score 0.5843401272060895
#
# macro_f1 :  0.53925676329542
#
# micro_f1 :  0.7265639625022534
#
# weighted_f1 :  0.7138304770873515

# %% [markdown]
#                                                       precision    recall  f1-score   support
#
#                                        pacing rhythm       0.88      0.85      0.86        59
#                                prolonged qt interval       0.34      0.73      0.46       302
#                                  atrial fibrillation       0.71      0.93      0.80       695
#                                       atrial flutter       0.51      0.56      0.53        62
#                             left bundle branch block       0.79      0.88      0.83       209
#                                       qwave abnormal       0.35      0.17      0.23       202
#                                      t wave abnormal       0.40      0.75      0.53       934
#                                prolonged pr interval       0.28      0.78      0.42        68
#                                     low qrs voltages       0.44      0.24      0.31       112
#                                  1st degree av block       0.50      0.89      0.64       479
#                         premature atrial contraction       0.39      0.44      0.46       389
#                                  left axis deviation       0.66      0.92      0.77      1217
#                                    sinus bradycardia       0.54      0.93      0.69       471
#                                          bradycardia       0.33      0.53      0.45        58
#                                         sinus rhythm       0.86      0.98      0.92      4169
#                                    sinus tachycardia       0.72      0.93      0.81       482
#                   premature ventricular contractions       0.20      0.39      0.27       110
#                                     sinus arrhythmia       0.26      0.10      0.15       248
#                       left anterior fascicular block       0.64      0.87      0.74       361
#                                 right axis deviation       0.38      0.77      0.57        86
#                                     t wave inversion       0.16      0.24      0.19       221
#     nonspecific intraventricular conduction disorder       0.41      0.24      0.30       199
#                 incomplete right bundle branch block       0.38      0.34      0.36       322
#                   complete right bundle branch block       0.73      0.90      0.81       615
#
#                                            micro avg       0.63      0.82      0.73     12070
#                                            macro avg       0.50      0.64      0.54     12070
#                                         weighted avg       0.65      0.82      0.71     12070
#                                          samples avg       0.71      0.85      0.74     12070

# %% [markdown]
# ![__results___51_373 (4).png](attachment:05cecdb3-5282-459c-b8f7-d0f84d6bde97.png)
